# %%
from plot import *

# %% [markdown]
# # Numerical Extensions of Section 4

# %% [markdown]
# ## Comparison between A1 and A3

# %%
plot_comparison_of_a1_a3()

# %% [markdown]
# ## Comparative Benefits of Misalignment Extension of Theorem 1

# %%
# Figure 4
comparion_between_aligned_and_misaligned_algorithm()
comparion_between_aligned_algorithms()

# %%
# Figure 5
comparion_between_aligned_and_misaligned_algorithm_RUM()
comparion_between_aligned_algorithms_RUM()

# %% [markdown]
# # Numerical Extensions of Section 5

# %% [markdown]
# ## Uplift with Misalignment

# %%
# Figure 6.1
comparion_between_algorithms_over_noncollaboration()
# Figure 6.2
comparion_between_aligned_algorithms_over_noncollaboration()

# %%
# Figure 7.1
comparion_between_algorithms_over_noncollaboration_RUM()
# Figure 7.2
comparion_between_aligned_algorithms_over_noncollaboration_RUM()

# %% [markdown]
# ## Performance of MIP

# %%
# Figure 8 and 9
plot_running_time(True)

# %% [markdown]
# ## Tensions between Uplift and Social Welfare

# %%
# Figure 10 to 13
plot_social_welfare_uplift(from_stored=True)

# %% [markdown]
# ## Small Noise Faciliates Uplift

# %%
# Figure 14
plot_minimum_noise_for_uplift(from_stored=True)
